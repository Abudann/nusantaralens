# %%
import pandas as pd

# BACA FILE EXCEL

laki = pd.read_excel('/content/Penduduk Laki Laki Yogyakarta.xlsx', header=1)
perempuan = pd.read_excel('/content/Penduduk Perempuan Yogyakarta.xlsx', header=1)

# RENAME KOLOM

laki.columns = [
    'Kelompok_Umur',
    2021,
    2022,
    2023,
    2024,
    2025,
    2026
]

perempuan.columns = [
    'Kelompok_Umur',
    2021,
    2022,
    2023,
    2024,
    2025,
    2026
]
# HAPUS BARIS KOSONG

laki = laki.dropna(how='all')
perempuan = perempuan.dropna(how='all')

# HAPUS BARIS JUMLAH & CATATAN

laki = laki[
    ~laki['Kelompok_Umur'].astype(str).str.contains(
        'Jumlah|Catatan',
        case=False,
        na=False
    )
]

perempuan = perempuan[
    ~perempuan['Kelompok_Umur'].astype(str).str.contains(
        'Jumlah|Catatan',
        case=False,
        na=False
    )
]

# UBAH DATA JADI NUMERIK

kolom_tahun = [2021, 2022, 2023, 2024, 2025, 2026]

for col in kolom_tahun:
    laki[col] = pd.to_numeric(laki[col], errors='coerce')
    perempuan[col] = pd.to_numeric(perempuan[col], errors='coerce')

# TAMBAH KOLOM GENDER

laki['Gender'] = 'Laki-laki'
perempuan['Gender'] = 'Perempuan'

# GABUNG DATA

df = pd.concat([laki, perempuan], ignore_index=True)

# CEK DATA

print(df.head())

print("\nMissing Value:")
print(df.isnull().sum())

print("\nJumlah Duplikat:")
print(df.duplicated().sum())

# HITUNG TOTAL PENDUDUK

total_laki = laki[kolom_tahun].sum()
total_perempuan = perempuan[kolom_tahun].sum()

# TABEL TOTAL

total_penduduk = pd.DataFrame({
    'Tahun': kolom_tahun,
    'Laki-laki': total_laki.values,
    'Perempuan': total_perempuan.values
})

print("\nTotal Penduduk:")
print(total_penduduk)

# 11. SIMPAN HASIL

df.to_excel('Data_Gabungan_Yogyakarta.xlsx', index=False)

total_penduduk.to_excel('Total_Penduduk_Yogyakarta.xlsx', index=False)

print("\nData berhasil disimpan")
# Out:
#   Kelompok_Umur    2021    2022    2023    2024    2025    2026     Gender
# 0         0 - 4  123.97  124.03  123.89  123.58  123.12  121.82  Laki-laki
# 1         5 - 9  126.73  126.13  125.60  125.11  124.62  124.90  Laki-laki
# 2       10 - 14  131.11  130.48  129.77  129.02  128.29  127.61  Laki-laki
# 3       15 - 19  134.19  134.29  134.32  134.19  133.86  133.34  Laki-laki
# 4       20 - 24  137.18  137.54  137.76  137.92  138.06  138.21  Laki-laki
#
# Missing Value:
# Kelompok_Umur    0
# 2021             0
# 2022             0
# 2023             0
# 2024             0
# 2025             0
# 2026             0
# Gender           0
# dtype: int64
#
# Jumlah Duplikat:
# 0
#
# Total Penduduk:
#    Tahun  Laki-laki  Perempuan
# 0   2021    1826.80    1861.00
# 1   2022    1838.42    1874.14
# 2   2023    1849.55    1886.97
# 3   2024    1860.12    1899.37
# 4   2025    1870.15    1911.43
# 5   2026    1879.69    1923.07
#
# Data berhasil disimpan
